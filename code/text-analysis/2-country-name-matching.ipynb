# %%
import pandas as pd
from tqdm import tqdm
from os.path import isfile
import concurrent.futures
import numpy as np

# %%
def add_word_boundaries(df):
    # Assuming this function adds word boundaries to the country names
    return df.applymap(lambda x: f'\\b{x}\\b')

# %%
def process_chunk(chunk, speeches):

    for name, regex in chunk:
        
        print("Processing", name)
        name = name.lower()
        fname = f"../output/countries-matching/{name}.feather"

        if isfile(fname):
            print(fname, "already exists")
            continue

        results = speeches['speech'].str.contains(regex, case=False)
        results = pd.DataFrame(results).rename(columns={"speech": name})
        results.to_feather(fname)

# %%
def main():
    
    # Column names
    languages = [
        'bg', 'hr', 'cs', 'da', 'nl', 'et', 'fi', 'fr', 'de', 'el', 'hu', 'ga', 
        'it', 'lv', 'lt', 'mt', 'pl', 'pt', 'ro', 'sk', 'sl', 'es', 'sv', 'en'
    ]
        
    # Reads the data in
    speeches = pd.read_feather("../output/processed/all-speeches-df.feather")
    country_names = pd.read_csv("../output/country-names/country-names-manual-revision.csv")
    
    # Saves the country names
    english_names = country_names['en']
    
    # Add word boundaries
    country_names = country_names[languages]
    country_names = add_word_boundaries(country_names)
    
    # Creates the regex patterns
    regex_patterns = country_names[languages].apply(lambda row: '|'.join(val.strip() for val in row), axis=1)    
    
    # Creates name and regex matches
    pairs = list(zip(english_names, regex_patterns))
    
    # Discover how many CPU cores we have available
    max_workers=multiprocessing.cpu_count()
    
    # Splits the pairs in this many chunks
    chunks = np.array_split(pairs, max_workers)

    
    # Process the chunks in parallel
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        
        futures = [executor.submit(process_chunk, chunk, speeches) for chunk in chunks]
        
        for future in concurrent.futures.as_completed(futures):
            future.result()
    
    print("Processing completed.")

# %%
# Run the main function
main()
# Out:
# Processing Afghanistan
# ../output/countries-matching/afghanistan.feather already exists
# Processing Albania
# ../output/countries-matching/albania.feather already exists
# Processing Algeria
# ../output/countries-matching/algeria.feather already exists
# Processing Andorra
# ../output/countries-matching/andorra.feather already exists
# Processing Angola
# ../output/countries-matching/angola.feather already exists
# Processing Antigua and Barbuda
# ../output/countries-matching/antigua and barbuda.feather already exists
# Processing Argentina
# ../output/countries-matching/argentina.feather already exists
# Processing Armenia
# ../output/countries-matching/armenia.feather already exists
# Processing Australia
# ../output/countries-matching/australia.feather already exists
# Processing Austria
# ../output/countries-matching/austria.feather already exists
# Processing Azerbaijan
# Processing Bangladesh
# ../output/countries-matching/bangladesh.feather already exists
# Processing Barbados
# ../output/countries-matching/azerbaijan.feather already exists
# Processing Bahamas
# ../output/countries-matching/bahamas.feather already exists
# Processing Bahrain
# ../output/countries-matching/barbados.feather already exists
# Processing Belarus
# ../output/countries-matching/belarus.feather already exists
# Processing Belgium
# ../output/countries-matching/bahrain.feather already exists
# Processing Burkina Faso
# Processing Costa Rica
# ../output/countries-matching/belgium.feather already exists
# Processing Belize
# Processing Ecuador
# ../output/countries-matching/belize.feather already exists
# Processing Benin
# ../output/countries-matching/benin.feather already exists
# Processing Bhutan
# Processing Gambia
# ../output/countries-matching/bhutan.feather already exists
# Processing Bolivia
# ../output/countries-matching/bolivia.feather already exists
# Processing Bosnia and Herzegovina
# ../output/countries-matching/bosnia and herzegovina.feather already exists
# Processing Botswana
# ../output/countries-matching/botswana.feather already exists
# Processing Brazil
# ../output/countries-matching/brazil.feather already exists
# Processing Brunei
# ../output/countries-matching/brunei.feather already exists
# Processing Bulgaria
# Processing Hungary
# Processing Kazakhstan
# Processing Lithuania
# Processing Micronesia
# Processing Nicaragua
# Processing Philippines
# Processing Samoa
# Processing Somalia
# Processing East Timor
# Processing Tanzania
# Processing Niger
# Processing Iceland
# Processing Luxembourg
# Processing Georgia
# Processing United States
# Processing Egypt
# Processing Poland
# Processing Kenya
# Processing Burundi
# Processing Monaco
# Processing Ivory Coast
# Processing Togo
# Processing San Marino
# Processing South Africa
# Processing Nigeria
# Processing Madagascar
# Processing El Salvador
# Processing Germany
# Processing Kiribati
# Processing Cape Verde
# Processing Portugal
# Processing Mongolia
# Processing Tonga
# Processing Croatia
# Processing Uruguay
# Processing India
# Processing South Sudan
# Processing São Tomé and Príncipe
# Processing North Macedonia
# Processing Malawi
# Processing Qatar
# Processing Kuwait
# Processing Cambodia
# Processing Ghana
# Processing Montenegro
# Processing Trinidad and Tobago
# Processing Cuba
# Processing Uzbekistan
# Processing Equatorial Guinea
# Processing Indonesia
# Processing Malaysia
# Processing Greece
# Processing South Korea
# Processing Cameroon
# Processing Kyrgyzstan
# Processing Tunisia
# Processing Spain
# Processing Norway
# Processing Morocco
# Processing Saudi Arabia
# ProcessingProcessing Vanuatu
#  Cyprus
# Processing Eritrea
# Processing Maldives
# Processing Grenada
# Processing Turkey
# Processing Oman
# Processing Canada
# Processing Laos
# Processing Mozambique
# Processing Venezuela
# Processing Moldova
# Processing Czech Republic
# Processing Iran
# Processing Sri Lanka
# Processing Estonia
# Processing Senegal
# Processing Mali
# Processing Guatemala
# Processing Turkmenistan
# Processing Latvia
# Processing Pakistan
# Processing Central African Republic
# Processing Myanmar
# Processing North Korea
# Processing Vietnam
# Processing Romania
# Processing Eswatini
# Processing Iraq
# Processing Sudan
# Processing Guinea
# Processing Tuvalu
# Processing Malta
# Processing Lebanon
# Processing Palau
# Processing Namibia
# Processing Chad
# Processing Serbia
# Processing Yemen
# Processing Russia
# Processing Democratic Republic of the Congo
# Processing Guinea-Bissau
# Processing Lesotho
# Processing Uganda
# Processing Marshall Islands
# Processing Ethiopia
# Processing Panama
# Processing Nauru
# Processing Ireland
# Processing Zambia
# Processing Rwanda
# Processing Chile
# Processing Suriname
# Processing Denmark
# Processing Seychelles
# Processing Liberia
# Processing Guyana
# Processing Ukraine
# Processing Fiji
# Processing Nepal
# Processing Papua New Guinea
# Processing Mauritania
# Processing China
# Processing Saint Kitts and Nevis
# Processing Djibouti
# Processing Zimbabwe
# Processing Israel
# Processing Sweden
# Processing Libya
# Processing Haiti
# Processing United Arab Emirates
# Processing Netherlands
# Processing Sierra Leone
# Processing Finland
# Processing Paraguay
# Processing Mauritius
# Processing Colombia
# Processing Dominica
# Processing Palestine
# Processing Saint Lucia
# Processing Liechtenstein
# Processing Honduras
# Processing United Kingdom
# Processing Italy
# Processing New Zealand
# Processing Switzerland
# Processing Peru
# Processing Mexico
# Processing France
# Processing Comoros
# Processing Dominican Republic
# Processing Singapore
# Processing Vatican
# Processing Saint Vincent and the Grenadines
# Processing Gabon
# Processing Jamaica
# Processing Republic of the Congo
# Processing Syria
# Processing Slovakia
# Processing Japan
# Processing Tajikistan
# Processing Slovenia
# Processing Jordan
# Processing Thailand
# Processing Solomon Islands
# Processing completed.

# %%
from os.path import isfile
import pandas as pd
import re
from tqdm import tqdm
from concurrent.futures import ProcessPoolExecutor
import multiprocessing

# %%
# Function to add word boundaries to each entry
def add_word_boundaries(df):
    return df.applymap(lambda x: r'\b' + x + r'\b')

# %%
def main():
    
    # This is defined inside the function so it can access speeches in the main scope
    def find_matches(pair):
        name, regex = pair
        print("Processing", name)
        name = name.lower()
        fname = f"../output/countries-matching/{name}.feather"

        if isfile(fname):
            print(fname, "already exists")
            return

        # Compute-heavy part
        results = speeches['speech'].str.contains(regex, case=False)
        results = pd.DataFrame(results).rename(columns={"speech": name})
        results.to_feather(fname)
        
    
    # Column names
    languages = [
        'bg', 'hr', 'cs', 'da', 'nl', 'et', 'fi', 'fr', 'de', 'el', 'hu', 'ga', 
        'it', 'lv', 'lt', 'mt', 'pl', 'pt', 'ro', 'sk', 'sl', 'es', 'sv', 'en'
    ]
        
    # Reads the data in
    speeches = pd.read_feather("../output/processed/all-speeches-df.feather")
    country_names = pd.read_csv("../output/country-names/country-names-manual-revision.csv")

    # Saves the country names
    english_names = country_names['en']
    
    # Add word boundaries
    country_names = country_names[languages]
    country_names = add_word_boundaries(country_names)
    
    # Creates the regex patterns
    regex_patterns = country_names[languages].apply(lambda row: '|'.join(val.strip() for val in row), axis=1)    
    
    # Iterates pair wise with the regex patterns and the names
    pairs = zip(english_names, regex_patterns)

    for pair in pairs:
        find_matches(pair)

# %%
# %%time
if __name__ == '__main__':
    main()
# Out:
# Processing Afghanistan
# ../output/countries-matching/afghanistan.feather already exists
# Processing Albania
# ../output/countries-matching/albania.feather already exists
# Processing Algeria
# ../output/countries-matching/algeria.feather already exists
# Processing Andorra
# ../output/countries-matching/andorra.feather already exists
# Processing Angola
# ../output/countries-matching/angola.feather already exists
# Processing Antigua and Barbuda
# ../output/countries-matching/antigua and barbuda.feather already exists
# Processing Argentina
# ../output/countries-matching/argentina.feather already exists
# Processing Armenia
# ../output/countries-matching/armenia.feather already exists
# Processing Australia
# ../output/countries-matching/australia.feather already exists
# Processing Austria
# ../output/countries-matching/austria.feather already exists
# Processing Azerbaijan
# ../output/countries-matching/azerbaijan.feather already exists
# Processing Bahamas
# ../output/countries-matching/bahamas.feather already exists
# Processing Bahrain
# ../output/countries-matching/bahrain.feather already exists
# Processing Bangladesh
# ../output/countries-matching/bangladesh.feather already exists
# Processing Barbados
# ../output/countries-matching/barbados.feather already exists
# Processing Belarus
# ../output/countries-matching/belarus.feather already exists
# Processing Belgium
# ../output/countries-matching/belgium.feather already exists
# Processing Belize
# ../output/countries-matching/belize.feather already exists
# Processing Benin
# ../output/countries-matching/benin.feather already exists
# Processing Bhutan
# ../output/countries-matching/bhutan.feather already exists
# Processing Bolivia
# ../output/countries-matching/bolivia.feather already exists
# Processing Bosnia and Herzegovina
# ../output/countries-matching/bosnia and herzegovina.feather already exists
# Processing Botswana
# ../output/countries-matching/botswana.feather already exists
# Processing Brazil
# ../output/countries-matching/brazil.feather already exists
# Processing Brunei
# ../output/countries-matching/brunei.feather already exists
# Processing Bulgaria
# ../output/countries-matching/bulgaria.feather already exists
# Processing Burkina Faso
# ../output/countries-matching/burkina faso.feather already exists
# Processing Burundi
# ../output/countries-matching/burundi.feather already exists
# Processing Cape Verde
# ../output/countries-matching/cape verde.feather already exists
# Processing Cambodia
# ../output/countries-matching/cambodia.feather already exists
# Processing Cameroon
# ../output/countries-matching/cameroon.feather already exists
# Processing Canada
# ../output/countries-matching/canada.feather already exists
# Processing Central African Republic
# ../output/countries-matching/central african republic.feather already exists
# Processing Chad
# ../output/countries-matching/chad.feather already exists
# Processing Chile
# ../output/countries-matching/chile.feather already exists
# Processing China
# ../output/countries-matching/china.feather already exists
# Processing Colombia
# ../output/countries-matching/colombia.feather already exists
# Processing Comoros
# ../output/countries-matching/comoros.feather already exists
# Processing Republic of the Congo
# ../output/countries-matching/republic of the congo.feather already exists
# Processing Costa Rica
# ../output/countries-matching/costa rica.feather already exists
# Processing Ivory Coast
# ../output/countries-matching/ivory coast.feather already exists
# Processing Croatia
# ../output/countries-matching/croatia.feather already exists
# Processing Cuba
# ../output/countries-matching/cuba.feather already exists
# Processing Cyprus
# ../output/countries-matching/cyprus.feather already exists
# Processing Czech Republic
# ../output/countries-matching/czech republic.feather already exists
# Processing North Korea
# ../output/countries-matching/north korea.feather already exists
# Processing Democratic Republic of the Congo
# ../output/countries-matching/democratic republic of the congo.feather already exists
# Processing Denmark
# ../output/countries-matching/denmark.feather already exists
# Processing Djibouti
# ../output/countries-matching/djibouti.feather already exists
# Processing Dominica
# ../output/countries-matching/dominica.feather already exists
# Processing Dominican Republic
# ../output/countries-matching/dominican republic.feather already exists
# Processing Ecuador
# ../output/countries-matching/ecuador.feather already exists
# Processing Egypt
# ../output/countries-matching/egypt.feather already exists
# Processing El Salvador
# ../output/countries-matching/el salvador.feather already exists
# Processing Equatorial Guinea
# ../output/countries-matching/equatorial guinea.feather already exists
# Processing Eritrea
# ../output/countries-matching/eritrea.feather already exists
# Processing Estonia
# ../output/countries-matching/estonia.feather already exists
# Processing Eswatini
# ../output/countries-matching/eswatini.feather already exists
# Processing Ethiopia
# ../output/countries-matching/ethiopia.feather already exists
# Processing Fiji
# ../output/countries-matching/fiji.feather already exists
# Processing Finland
# ../output/countries-matching/finland.feather already exists
# Processing France
# ../output/countries-matching/france.feather already exists
# Processing Gabon
# ../output/countries-matching/gabon.feather already exists
# Processing Gambia
# ../output/countries-matching/gambia.feather already exists
# Processing Georgia
# ../output/countries-matching/georgia.feather already exists
# Processing Germany
# ../output/countries-matching/germany.feather already exists
# Processing Ghana
# ../output/countries-matching/ghana.feather already exists
# Processing Greece
# ../output/countries-matching/greece.feather already exists
# Processing Grenada
# ../output/countries-matching/grenada.feather already exists
# Processing Guatemala
# ../output/countries-matching/guatemala.feather already exists
# Processing Guinea
# ../output/countries-matching/guinea.feather already exists
# Processing Guinea-Bissau
# ../output/countries-matching/guinea-bissau.feather already exists
# Processing Guyana
# ../output/countries-matching/guyana.feather already exists
# Processing Haiti
# ../output/countries-matching/haiti.feather already exists
# Processing Honduras
# ../output/countries-matching/honduras.feather already exists
# Processing Hungary
# ../output/countries-matching/hungary.feather already exists
# Processing Iceland
# ../output/countries-matching/iceland.feather already exists
# Processing India
# ../output/countries-matching/india.feather already exists
# Processing Indonesia
# ../output/countries-matching/indonesia.feather already exists
# Processing Iran
# ../output/countries-matching/iran.feather already exists
# Processing Iraq
# ../output/countries-matching/iraq.feather already exists
# Processing Ireland
# ../output/countries-matching/ireland.feather already exists
# Processing Israel
# ../output/countries-matching/israel.feather already exists
# Processing Italy
# ../output/countries-matching/italy.feather already exists
# Processing Jamaica
# ../output/countries-matching/jamaica.feather already exists
# Processing Japan
# ../output/countries-matching/japan.feather already exists
# Processing Jordan
# ../output/countries-matching/jordan.feather already exists
# Processing Kazakhstan
# ../output/countries-matching/kazakhstan.feather already exists
# Processing Kenya
# ../output/countries-matching/kenya.feather already exists
# Processing Kiribati
# ../output/countries-matching/kiribati.feather already exists
# Processing Kuwait
# ../output/countries-matching/kuwait.feather already exists
# Processing Kyrgyzstan
# ../output/countries-matching/kyrgyzstan.feather already exists
# Processing Laos
# ../output/countries-matching/laos.feather already exists
# Processing Latvia
# ../output/countries-matching/latvia.feather already exists
# Processing Lebanon
# ../output/countries-matching/lebanon.feather already exists
# Processing Lesotho
# ../output/countries-matching/lesotho.feather already exists
# Processing Liberia
# ../output/countries-matching/liberia.feather already exists
# Processing Libya
# ../output/countries-matching/libya.feather already exists
# Processing Liechtenstein
# ../output/countries-matching/liechtenstein.feather already exists
# Processing Lithuania
# ../output/countries-matching/lithuania.feather already exists
# Processing Luxembourg
# ../output/countries-matching/luxembourg.feather already exists
# Processing Madagascar
# ../output/countries-matching/madagascar.feather already exists
# Processing Malawi
# ../output/countries-matching/malawi.feather already exists
# Processing Malaysia
# ../output/countries-matching/malaysia.feather already exists
# Processing Maldives
# ../output/countries-matching/maldives.feather already exists
# Processing Mali
# ../output/countries-matching/mali.feather already exists
# Processing Malta
# ../output/countries-matching/malta.feather already exists
# Processing Marshall Islands
# ../output/countries-matching/marshall islands.feather already exists
# Processing Mauritania
# ../output/countries-matching/mauritania.feather already exists
# Processing Mauritius
# ../output/countries-matching/mauritius.feather already exists
# Processing Mexico
# ../output/countries-matching/mexico.feather already exists
# Processing Micronesia
# ../output/countries-matching/micronesia.feather already exists
# Processing Monaco
# ../output/countries-matching/monaco.feather already exists
# Processing Mongolia
# ../output/countries-matching/mongolia.feather already exists
# Processing Montenegro
# ../output/countries-matching/montenegro.feather already exists
# Processing Morocco
# ../output/countries-matching/morocco.feather already exists
# Processing Mozambique
# ../output/countries-matching/mozambique.feather already exists
# Processing Myanmar
# ../output/countries-matching/myanmar.feather already exists
# Processing Namibia
# ../output/countries-matching/namibia.feather already exists
# Processing Nauru
# ../output/countries-matching/nauru.feather already exists
# Processing Nepal
# ../output/countries-matching/nepal.feather already exists
# Processing Netherlands
# ../output/countries-matching/netherlands.feather already exists
# Processing New Zealand
# ../output/countries-matching/new zealand.feather already exists
# Processing Nicaragua
# ../output/countries-matching/nicaragua.feather already exists
# Processing Niger
# ../output/countries-matching/niger.feather already exists
# Processing Nigeria
# ../output/countries-matching/nigeria.feather already exists
# Processing North Macedonia
# ../output/countries-matching/north macedonia.feather already exists
# Processing Norway
# ../output/countries-matching/norway.feather already exists
# Processing Oman
# ../output/countries-matching/oman.feather already exists
# Processing Pakistan
# ../output/countries-matching/pakistan.feather already exists
# Processing Palau
# ../output/countries-matching/palau.feather already exists
# Processing Panama
# ../output/countries-matching/panama.feather already exists
# Processing Papua New Guinea
# ../output/countries-matching/papua new guinea.feather already exists
# Processing Paraguay
# ../output/countries-matching/paraguay.feather already exists
# Processing Peru
# ../output/countries-matching/peru.feather already exists
# Processing Philippines
# ../output/countries-matching/philippines.feather already exists
# Processing Poland
# ../output/countries-matching/poland.feather already exists
# Processing Portugal
# ../output/countries-matching/portugal.feather already exists
# Processing Qatar
# ../output/countries-matching/qatar.feather already exists
# Processing South Korea
# ../output/countries-matching/south korea.feather already exists
# Processing Moldova
# ../output/countries-matching/moldova.feather already exists
# Processing Romania
# ../output/countries-matching/romania.feather already exists
# Processing Russia
# ../output/countries-matching/russia.feather already exists
# Processing Rwanda
# ../output/countries-matching/rwanda.feather already exists
# Processing Saint Kitts and Nevis
# ../output/countries-matching/saint kitts and nevis.feather already exists
# Processing Saint Lucia
# ../output/countries-matching/saint lucia.feather already exists
# Processing Saint Vincent and the Grenadines
# ../output/countries-matching/saint vincent and the grenadines.feather already exists
# Processing Samoa
# ../output/countries-matching/samoa.feather already exists
# Processing San Marino
# ../output/countries-matching/san marino.feather already exists
# Processing São Tomé and Príncipe
# ../output/countries-matching/são tomé and príncipe.feather already exists
# Processing Saudi Arabia
# ../output/countries-matching/saudi arabia.feather already exists
# Processing Senegal
# ../output/countries-matching/senegal.feather already exists
# Processing Serbia
# ../output/countries-matching/serbia.feather already exists
# Processing Seychelles
# ../output/countries-matching/seychelles.feather already exists
# Processing Sierra Leone
# ../output/countries-matching/sierra leone.feather already exists
# Processing Singapore
# ../output/countries-matching/singapore.feather already exists
# Processing Slovakia
# ../output/countries-matching/slovakia.feather already exists
# Processing Slovenia
# ../output/countries-matching/slovenia.feather already exists
# Processing Solomon Islands
# ../output/countries-matching/solomon islands.feather already exists
# Processing Somalia
# ../output/countries-matching/somalia.feather already exists
# Processing South Africa
# ../output/countries-matching/south africa.feather already exists
# Processing South Sudan
# ../output/countries-matching/south sudan.feather already exists
# Processing Spain
# ../output/countries-matching/spain.feather already exists
# Processing Sri Lanka
# ../output/countries-matching/sri lanka.feather already exists
# Processing Sudan
# ../output/countries-matching/sudan.feather already exists
# Processing Suriname
# ../output/countries-matching/suriname.feather already exists
# Processing Sweden
# ../output/countries-matching/sweden.feather already exists
# Processing Switzerland
# ../output/countries-matching/switzerland.feather already exists
# Processing Syria
# ../output/countries-matching/syria.feather already exists
# Processing Tajikistan
# ../output/countries-matching/tajikistan.feather already exists
# Processing Thailand
# ../output/countries-matching/thailand.feather already exists
# Processing East Timor
# ../output/countries-matching/east timor.feather already exists
# Processing Togo
# ../output/countries-matching/togo.feather already exists
# Processing Tonga
# ../output/countries-matching/tonga.feather already exists
# Processing Trinidad and Tobago
# ../output/countries-matching/trinidad and tobago.feather already exists
# Processing Tunisia
# ../output/countries-matching/tunisia.feather already exists
# Processing Turkey
# ../output/countries-matching/turkey.feather already exists
# Processing Turkmenistan
# ../output/countries-matching/turkmenistan.feather already exists
# Processing Tuvalu
# ../output/countries-matching/tuvalu.feather already exists
# Processing Uganda
# ../output/countries-matching/uganda.feather already exists
# Processing Ukraine
# ../output/countries-matching/ukraine.feather already exists
# Processing United Arab Emirates
# ../output/countries-matching/united arab emirates.feather already exists
# Processing United Kingdom
# ../output/countries-matching/united kingdom.feather already exists
# Processing Tanzania
# ../output/countries-matching/tanzania.feather already exists
# Processing United States
# ../output/countries-matching/united states.feather already exists
# Processing Uruguay
# ../output/countries-matching/uruguay.feather already exists
# Processing Uzbekistan
# ../output/countries-matching/uzbekistan.feather already exists
# Processing Vanuatu
# ../output/countries-matching/vanuatu.feather already exists
# Processing Venezuela
# ../output/countries-matching/venezuela.feather already exists
# Processing Vietnam
# ../output/countries-matching/vietnam.feather already exists
# Processing Yemen
# ../output/countries-matching/yemen.feather already exists
# Processing Zambia
# ../output/countries-matching/zambia.feather already exists
# Processing Zimbabwe
# ../output/countries-matching/zimbabwe.feather already exists
# Processing Palestine
# ../output/countries-matching/palestine.feather already exists
# Processing Vatican
# ../output/countries-matching/vatican.feather already exists
# CPU times: user 1.6 s, sys: 1.31 s, total: 2.91 s
# Wall time: 2.66 s

# %%
speec
